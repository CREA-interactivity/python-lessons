# %% [markdown]
# # 🐍 Python Basics — Tinker Notebook
#
# Welcome! In this notebook you'll run little bits of Python code and mess with them.
#
# **How this works:**
# - Click into a gray box (a "cell") and press **Shift + Enter** to run it.
# - Change the numbers, words, or code and run it again — you can't break anything permanently.
# - Every section has an example, then a "🎯 Your Turn" challenge.
#
# Let's go!

# %% [markdown]
# ## 1. Printing stuff

# %%
print("Hello, world!")
print("Python is pretty cool.")

# %% [markdown]
# **🎯 Your Turn:** Change the messages below to say hello to yourself and a friend.

# %%
print("Hello, ___!")
print("___ is my favorite thing.")

# %% [markdown]
# ## 2. Variables — storing information

# %%
name = "Alex"
age = 11
print("My name is", name)
print("I am", age, "years old")

# %% [markdown]
# **🎯 Your Turn:** Make your own `name` and `age` variables (use YOUR real info) and print them.

# %%
name = ""
age = 0
print("My name is", name)
print("I am", age, "years old")

# %% [markdown]
# ## 3. Math operations

# %%
a = 7
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Remainder (leftover after dividing):", a % b)
print("Power (a to the power of b):", a ** b)

# %% [markdown]
# **🎯 Your Turn:** Change `a` and `b` to two numbers of your choice. Before running, guess what each answer will be — were you right?

# %%
a = 0
b = 0

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)

# %% [markdown]
# ## 4. Strings — working with text

# %%
first = "Ada"
last = "Lovelace"
full_name = first + " " + last

print(full_name)
print(full_name.upper())
print(full_name.lower())
print("Number of letters:", len(full_name))

# %% [markdown]
# **🎯 Your Turn:** Combine your own first and last name, then print it in ALL CAPS.

# %%
first = ""
last = ""

# %% [markdown]
# ## 5. Getting input from a person

# %%
your_name = input("What's your name? ")
print("Nice to meet you, " + your_name + "!")

# %% [markdown]
# **🎯 Your Turn:** Ask the user for their favorite animal and print a silly sentence using it.

# %% [markdown]
# ## 6. Lists — a bunch of things in one variable

# %%
fruits = ["apple", "banana", "mango"]

print(fruits)
print("First fruit:", fruits[0])
print("Last fruit:", fruits[-1])

fruits.append("kiwi")
print("After adding kiwi:", fruits)

# %% [markdown]
# **🎯 Your Turn:** Make a list of your 3 favorite games or shows, print the second one, then add a 4th.

# %% [markdown]
# ## 7. If / else — making decisions

# %%
age = 12

if age >= 13:
    print("You're a teenager!")
else:
    print("Not a teenager yet.")

# %% [markdown]
# **🎯 Your Turn:** Write code that checks a number and prints "even" if it's even, or "odd" if it's odd.
#
# (Hint: a number is even if `number % 2 == 0`)

# %%
number = 4

# %% [markdown]
# ## 8. Loops — repeating things

# %%
for i in range(5):
    print("This is loop number", i)

# %%
fruits = ["apple", "banana", "mango"]

for fruit in fruits:
    print("I like", fruit)

# %% [markdown]
# **🎯 Your Turn:** Use a loop to print the numbers 1 through 10, but print "Buzz" instead whenever the number is divisible by 3.
#
# (Hint: `number % 3 == 0`)

# %% [markdown]
# ## 9. Functions — reusable blocks of code

# %%
def greet(person_name):
    print("Hey there, " + person_name + "!")

greet("Sam")
greet("Jordan")

# %% [markdown]
# **🎯 Your Turn:** Write a function called `double` that takes a number and prints double its value. Then call it with 3 different numbers.

# %%
def double(number):

# %% [markdown]
# ## 🏆 Final Challenge
#
# Combine what you learned! Write a program that:
# 1. Asks the user for their name and age using `input()`
# 2. Prints a greeting using their name
# 3. Uses an `if` statement to tell them whether they can vote yet (18+)
# 4. Uses a loop to count down from their age to 0
#
# Try it below — it's okay to ask for help or peek at earlier sections!
